# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
summary = pd.read_csv('../summary.csv')

# %%
sns.lineplot(x='epoch', y='train_loss', data=summary)
# Out:
# <Axes: xlabel='epoch', ylabel='train_loss'>

# %%
sns.lineplot(x='epoch', y='test_loss', data=summary)
# Out:
# <Axes: xlabel='epoch', ylabel='test_loss'>
